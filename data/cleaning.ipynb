# %% [markdown]
# # Data Cleaning and Preparation

# %% [markdown]
# ### Taking a look at the data, and preparing it for insertion into a database.

# %%
import pandas as pd
import json

# %%
with open('ICT_Bachelors_ENG.json') as f:
    data = json.load(f)

courses = [item['data']['realizationById'] for item in data]
courses_df = pd.json_normalize(courses)

courses_df.head()
# Out:
#               id           code                                     title  \
# 0   TTC2070-3016   TTC2070-3016          Project Management and Practices
# 1            NaN            NaN                                       NaN
# 2   TTC2040-3019   TTC2040-3019               Introduction to IoT systems
# 3  HTGP0060-3005  HTGP0060-3005                       Collaboration Tools
# 4  HTGP0500-3005  HTGP0500-3005  Digital Photography and Video Production
#
#    credits                                   degreeProgrammes  \
# 0      4.0  [{'id': '82940', 'title': 'Bachelor's Degree P...
# 1      NaN                                                NaN
# 2      3.0  [{'id': '82940', 'title': 'Bachelor's Degree P...
# 3      2.0  [{'id': '5158', 'title': 'Bachelor's Degree Pr...
# 4      5.0  [{'id': '5158', 'title': 'Bachelor's Degree Pr...
#
#                                        studentGroups   __typename  \
# 0  [{'id': '119696', 'code': 'TTV22S5', 'title': ...  Realization
# 1                                                NaN          NaN
# 2  [{'id': '104696', 'code': 'TIC22S1', 'title': ...  Realization
# 3  [{'id': '131501', 'code': 'HTK23S1', 'title': ...  Realization
# 4  [{'id': '104065', 'code': 'HTG22S1', 'title': ...  Realization
#
#                                            objective  \
# 0  Purpose:\r\nWorking in project format is very ...
# 1                                                NaN
# 2  Purpose and objectives:\r\nYou recognize the p...
# 3  Software development is teamwork. In order to ...
# 4  The object of the course\r\nDo you want to kno...
#
#                                      teachingMethods  \
# 0  - Flipped Learning \r\n- independent study\r\n...
# 1                                                NaN
# 2
# 3  - Lectures / real-time excercises in auditoriu...
# 4  The primary mode of delivery for this course a...
#
#                                              content  ... seats.min seats.max  \
# 0  - basics of project work\r\n- roles of actors ...  ...      20.0      70.0
# 1                                                NaN  ...       NaN       NaN
# 2  Parts of IoT value chain\r\n- Sensing solution...  ...      20.0      35.0
# 3  Tools for communication\r\nTools for task mana...  ...      20.0     100.0
# 4  In the course you will be focused on the basic...  ...      20.0      30.0
#
#   seats.__typename createdFromProgramme.id  \
# 0            Seats                   50107
# 1              NaN                     NaN
# 2            Seats                   50088
# 3            Seats                   51876
# 4            Seats                   49926
#
#                           createdFromProgramme.title  \
# 0  Bachelor's Degree Programme in Information and...
# 1                                                NaN
# 2  Bachelor's Degree Programme in Information and...
# 3  Bachelor's Degree Programme in Business Inform...
# 4  Bachelor's Degree Programme in Business Inform...
#
#   createdFromProgramme.code createdFromProgramme.link  \
# 0                 TTV2022SS
# 1                       NaN                       NaN
# 2                 TIC2022SS
# 3                 HTG2023SS
# 4                 HTG2022SS
#
#   createdFromProgramme.__typename office createdFromProgramme
# 0                      Curriculum    NaN                  NaN
# 1                             NaN    NaN                  NaN
# 2                      Curriculum    NaN                  NaN
# 3                      Curriculum    NaN                  NaN
# 4                      Curriculum    NaN                  NaN
#
# [5 rows x 53 columns]

# %%
courses_df.dropna(how='all', inplace=True)
print(f'Courses after dropping empty rows: {courses_df.shape[0]}')
# Out:
# Courses after dropping empty rows: 159

# %%
courses_df.columns
# Out:
# Index(['id', 'code', 'title', 'credits', 'degreeProgrammes', 'studentGroups',
#        '__typename', 'objective', 'teachingMethods', 'content',
#        'learningMaterial', 'teachingLanguage', 'teachers', 'teachingMethod',
#        'qualifications', 'evaluation', 'employerConnections', 'examSchedule',
#        'internationalConnections', 'workload', 'contentScheduling',
#        'informationOfCourse', 'furtherInformation', 'approveRejectDescription',
#        'evaluationScale', 'curriculum', 'relatedOffering', 'educationalFields',
#        'timing.start', 'timing.end', 'enrollment.start', 'enrollment.end',
#        'office.id', 'office.code', 'office.title', 'office.__typename',
#        'unit.id', 'unit.code', 'unit.title', 'unit.__typename',
#        'teachingMethodFull.online', 'teachingMethodFull.contact',
#        'teachingMethodFull.__typename', 'seats.min', 'seats.max',
#        'seats.__typename', 'createdFromProgramme.id',
#        'createdFromProgramme.title', 'createdFromProgramme.code',
#        'createdFromProgramme.link', 'createdFromProgramme.__typename',
#        'office', 'createdFromProgramme'],
#       dtype='object')

# %% [markdown]
# Useful columns in the data:
#
# - id
# - code
# - title
# - credits
# - __typename
# - objective
# - teachingMethods
# - content
# - unit.title
# - learningMaterial
# - teachers
# - teachingMethod
# - teachingMethodFull.online
# - teachingMethodFull.contact
# - qualifications
# - evaluation
# - employerConnections
# - examSchedule
# - internationalConnections
# - workload
# - contentScheduling
# - informationOfCourse
# - furtherInformation
# - evaluationScale
# - seats.min
# - seats.max
# - relatedOffering

# %%
columns_to_keep = [
    'id', 'code', 'title', 'credits', '__typename', 'objective', 'teachingMethods', 
    'content', 'unit.title', 'learningMaterial', 'teachers', 'teachingMethod', 
    'teachingMethodFull.online', 'teachingMethodFull.contact', 'qualifications', 
    'evaluation', 'employerConnections', 'examSchedule', 'internationalConnections', 
    'workload', 'contentScheduling', 'informationOfCourse', 'furtherInformation', 
    'evaluationScale', 'seats.min', 'seats.max', 'relatedOffering'
]

# Drop other columns
columns_to_drop = [col for col in courses_df.columns if col not in columns_to_keep]
courses_df = courses_df.drop(columns=columns_to_drop)

# %%
courses_df.rename(columns={'__typename': 'type_name', 'teachingMethods': 'teaching_methods', 'teachingMethod': 'teaching_method',
                            'learningMaterial': 'learning_material', 'unit.title': 'unit_title', 'teachingMethod': 'teaching_method',
                            'teachingMethodFull.online': 'teaching_method_online', 'teachingMethodFull.contact': 'teaching_method_contact',
                            'employerConnections': 'employer_connections', 'examSchedule': 'exam_schedule', 'internationalConnections': 'international_connections',
                            'contentScheduling': 'content_scheduling', 'informationOfCourse': 'course_information', 'furtherInformation': 'further_information',
                            'evaluationScale': 'evaluation_scale', 'seats.min': 'min_seats', 'seats.max': 'max_seats', 'relatedOffering': 'related_offering'}
                            , inplace=True)

# %% [markdown]
# Checking to see if `id` and `code` are always the same, if they are we can drop `id` and use `code` as the primary key:

# %%
rows_where_unequal = len(courses_df[courses_df['id'] != courses_df['code']])
print(f'Number of rows where id and code are not equal: {rows_where_unequal}')
# Out:
# Number of rows where id and code are not equal: 0

# %%
courses_df.drop(columns=['id'], inplace=True)

# %% [markdown]
# Finding out which columns contain objects, and making them into their own dataframes:

# %%
object_cols = courses_df.columns[courses_df.map(lambda x: isinstance(x, (list, dict))).any()].tolist()

print(f'Object columns: {object_cols}')
# Out:
# Object columns: ['teachers', 'related_offering']

# %%
teachers_data = []
related_offering_data = []

for index, row in courses_df.iterrows():
    teachers = row['teachers']
    if teachers is not None:
        for teacher in teachers:
            teachers_data.append({'name': teacher['name'], 'type': teacher['__typename'], 'course_code': row['code']})

    related_offerings = row['related_offering']
    if related_offerings is not None:
        for related_offering in related_offerings:
            related_offering_data.append({'code': related_offering['code'], 'title': related_offering['title'],
                                          'link': related_offering['link'], 'type': related_offering['__typename'],
                                          'course_code': row['code']})

degree_programmes_df = pd.DataFrame(teachers_data)
student_groups_df = pd.DataFrame(related_offering_data)

# %%
degree_programmes_df.head()
# Out:
#                name     type    course_code
# 0   Marko Rintamäki  Teacher   TTC2070-3016
# 1  Jouko Kotkansalo  Teacher   TTC2040-3019
# 2   Juha-Tapio Teno  Teacher  HTGP0060-3005
# 3  Kalle Raijonkari  Teacher  HTGP0500-3005
# 4     Jari Kuskelin  Teacher  HTGP0500-3005

# %%
student_groups_df.head()
# Out:
#                           code  \
# 0                   TTK20S1OTL
# 1                    TTK21KOHJ
# 2                    TTK22KOHJ
# 3  EXSTBUSINESSINFORMATIONTECH
# 4                  STUDYABROAD
#
#                                                title link        type  \
# 0              Ohjelmistotuotanto ja laadunvarmistus       Curriculum
# 1                           Ohjelmistoalan osaajaksi       Curriculum
# 2                           Ohjelmistoalan osaajaksi       Curriculum
# 3  Exchange Studies: Business Information Technol...       Curriculum
# 4  Incoming students - Special Study Programmes i...       Curriculum
#
#      course_code
# 0   TTC2070-3016
# 1   TTC2070-3016
# 2   TTC2070-3016
# 3  HTGP0500-3005
# 4  HTGP0500-3005

# %% [markdown]
# Dropping `teachers` and `related_offering` from the course data, as they now have their own dataframes.

# %%
courses_df.drop(columns=['teachers', 'related_offering'], inplace=True)

# %%
pd.set_option('display.max_columns', None)
courses_df.head()
# Out:
#             code                                     title  credits  \
# 0   TTC2070-3016          Project Management and Practices      4.0
# 2   TTC2040-3019               Introduction to IoT systems      3.0
# 3  HTGP0060-3005                       Collaboration Tools      2.0
# 4  HTGP0500-3005  Digital Photography and Video Production      5.0
# 5  HTGP0120-3002                           Business Basics      2.0
#
#      type_name                                          objective  \
# 0  Realization  Purpose:\r\nWorking in project format is very ...
# 2  Realization  Purpose and objectives:\r\nYou recognize the p...
# 3  Realization  Software development is teamwork. In order to ...
# 4  Realization  The object of the course\r\nDo you want to kno...
# 5  Realization  Understanding the business is essential for ev...
#
#                                     teaching_methods  \
# 0  - Flipped Learning \r\n- independent study\r\n...
# 2
# 3  - Lectures / real-time excercises in auditoriu...
# 4  The primary mode of delivery for this course a...
# 5  This implementation utilizes reverse learning,...
#
#                                              content  \
# 0  - basics of project work\r\n- roles of actors ...
# 2  Parts of IoT value chain\r\n- Sensing solution...
# 3  Tools for communication\r\nTools for task mana...
# 4  In the course you will be focused on the basic...
# 5  Marketing Basics\r\nFinancial Management\r\nFi...
#
#                                    learning_material teaching_method  \
# 0  Materials in the Gitlab environment.\r\n\r\nht...          Online
# 2                                                            Contact
# 3  Course material written by the teacher as well...         Contact
# 4  Long B. Complete Digital Photography, 2018\r\n...         Contact
# 5  - Teacher's materials and slides\r\n- 1336/199...         Contact
#
#                                       qualifications evaluation  \
# 0
# 2  Basics in Programming\r\nData Networks\r\nUse ...
# 3  Basic computer skills are required. You must b...
# 4  Basics for digital media -course needs to be p...
# 5                                                  -
#
#                                 employer_connections  \
# 0        - visiting lecturers\r\n- projektiharjoitus
# 2
# 3
# 4  Possible special lectures from the experts con...
# 5
#
#                                        exam_schedule  \
# 0  https://ttc2070.pages.labranet.jamk.fi/en/7-Ex...
# 2
# 3
# 4  There will be no exam during this course. The ...
# 5  The final exam is on week 43. On first contact...
#
#   international_connections  \
# 0                         -
# 2
# 3
# 4
# 5
#
#                                             workload  \
# 0  One credit (1 Cr) corresponds to an average of...
# 2
# 3                            Approximately 54 hours.
# 4  Course workload is 5 ECTS = approx. 135 hours....
# 5  One credit corresponds to an average of 27 hou...
#
#                                   content_scheduling  \
# 0  After course info-day you can proceed freely d...
# 2
# 3
# 4
# 5                        Weekly lessons / workshops.
#
#                                   course_information  \
# 0           http://ttc2070.pages.labranet.jamk.fi/en
# 2
# 3
# 4  This course is focused for the degree students...
# 5
#
#                                  further_information evaluation_scale  \
# 0  avoinExecution of course relays heavily on an ...        Pass/Fail
# 2                                                                 0-5
# 3      Avoin amk 10 (included in the total capacity)        Pass/Fail
# 4                         Edufutura 5\r\nAvoin amk 5              0-5
# 5  The course grade is determined as follows:\r\n...              0-5
#
#              unit_title teaching_method_online teaching_method_contact  \
# 0  School of Technology                      4                       0
# 2  School of Technology                      0                       3
# 3    School of Business                      0                       2
# 4    School of Business                      0                       5
# 5    School of Business                      0                       2
#
#    min_seats  max_seats
# 0       20.0       70.0
# 2       20.0       35.0
# 3       20.0      100.0
# 4       20.0       30.0
# 5       20.0       80.0
